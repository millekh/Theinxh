# %% [markdown]
# # TICE Final Presentation Demo
# Install dependencies and run the secure simulator.

# %%
# !pip install cryptography torch numpy

# %%
from tice_multi_agent_sim_final_presentation import run_sim
res = run_sim()
res
